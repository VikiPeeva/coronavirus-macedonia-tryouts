# %%
import geopandas
import json
import numpy as np
import pandas as pd

import math

# %%
mk_municipalities = geopandas.read_file("../local/mk_municipalities/mk_municipalities.geojson")
mk_cities = mk_municipalities.dissolve(by='entity_mk', aggfunc='sum')                                
# mk_cities['entity_mk'] = mk_cities.index
mk_cities['id'] = mk_cities.index
mk_cities
# Out:
#                                                             geometry  \
# entity_mk
# Јегуновце          POLYGON ((21.02797 42.02765, 21.02810 42.02753...
# Арачиново          POLYGON ((21.61108 42.08140, 21.61101 42.08098...
# Берово             POLYGON ((22.78298 41.78510, 22.78360 41.78545...
# Битола             POLYGON ((21.25219 40.89330, 21.24280 40.87920...
# Богданци           POLYGON ((22.52113 41.15881, 22.52180 41.15898...
# ...                                                              ...
# Центар Жупа        POLYGON ((20.66262 41.44884, 20.66553 41.44795...
# Чашка              POLYGON ((21.81383 41.49223, 21.81417 41.49180...
# Чешиново-Облешево  POLYGON ((22.21717 41.85944, 22.21745 41.85988...
# Чучер Сандево      POLYGON ((21.52347 42.19750, 21.52344 42.19761...
# Штип               POLYGON ((22.41569 41.72909, 22.41546 41.72934...
#
#                    latitude  longitude  area_sqkm   area  population  \
# entity_mk
# Јегуновце           42.0311    21.1290          0  174.0      10.790
# Арачиново           42.0185    21.5862          0   38.0      11.597
# Берово              41.6344    22.8027          0  597.0      13.941
# Битола              41.0402    21.2925          0  790.0      95.385
# Богданци            41.1772    22.5841          0  114.0       8.707
# ...                     ...        ...        ...    ...         ...
# Центар Жупа         41.4644    20.5799          0  107.0       6.519
# Чашка               41.5807    21.5939          0  727.0       7.673
# Чешиново-Облешево   41.8644    22.2896          0  133.0       7.490
# Чучер Сандево       42.1353    21.3885          0  215.0       8.493
# Штип                41.6824    22.1689          0  583.0      47.796
#
#                    scalerank  diss_me  adm0_sr  provnum_ne  ...  adm0_label  \
# entity_mk                                                   ...
# Јегуновце                 10     2963        1       20001  ...           5
# Арачиново                 10     2919        1       20057  ...           5
# Берово                    10     3004        1       20029  ...           5
# Битола                    10     2896        1       20040  ...           5
# Богданци                  10     2996        1       20025  ...           5
# ...                      ...      ...      ...         ...  ...         ...
# Центар Жупа               10     2951        1       20036  ...           5
# Чашка                     10     2922        1       20070  ...           5
# Чешиново-Облешево         10     2925        1       20058  ...           5
# Чучер Сандево             10     2926        1       20004  ...           5
# Штип                      10     2911        1       20046  ...           5
#
#                     gn_id   gns_id  gn_level  gns_level  min_label  max_label  \
# entity_mk
# Јегуновце          863858  9075623         1          1       10.0       11.0
# Арачиново          863831  9075577         1          1       10.0       11.0
# Берово             863485  9058335         1          1       10.0       11.0
# Битола             863486  9058342         1          1       10.0       11.0
# Богданци           862950  9043540         1          1       10.0       11.0
# ...                   ...      ...       ...        ...        ...        ...
# Центар Жупа        863841  9075602         1          1       10.0       11.0
# Чашка              863838  9075596         1          1       10.0       11.0
# Чешиново-Облешево  862977  9043609         1          1       10.0       11.0
# Чучер Сандево      863842  9075604         1          1       10.0       11.0
# Штип               863900  9075766         1          1       10.0       11.0
#
#                    min_zoom       ne_id                 id
# entity_mk
# Јегуновце              10.0  1159314547          Јегуновце
# Арачиново              10.0  1159314449          Арачиново
# Берово                 10.0  1159314569             Берово
# Битола                 10.0  1159314401             Битола
# Богданци               10.0  1159314555           Богданци
# ...                     ...         ...                ...
# Центар Жупа            10.0  1159314519        Центар Жупа
# Чашка                  10.0  1159314457              Чашка
# Чешиново-Облешево      10.0  1159314463  Чешиново-Облешево
# Чучер Сандево          10.0  1159314465      Чучер Сандево
# Штип                   10.0  1159314431               Штип
#
# [70 rows x 29 columns]

# %%
quarantine_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vR-Ul4NMiPvca7QH-RlYk2Q1hrVmjjGp5tr5n64l1z-SH5S2NoMeqjSd5Ulo171tHKM2Crfr7u0tpcz/pub?gid=325857359&single=true&output=csv")
quarantine_df
# Out:
#        Општина    Од датум  До датум
# 0        Дебар  2020-03-12       NaN
# 1  Центар Жупа  2020-03-12       NaN

# %%
mk_cities_quarantine = mk_cities.merge(quarantine_df, left_on='entity_mk', right_on='Општина', how='inner')

# %%
mk_cities_quarantine['dissolvefield'] = 1
quarantine = mk_cities_quarantine.dissolve(by='dissolvefield', aggfunc='sum')
quarantine
# Out:
#                                                         geometry  latitude  \
# dissolvefield
# 1              POLYGON ((20.68236 41.43111, 20.68161 41.43045...   83.0054
#
#                longitude  area_sqkm   area  population  scalerank  diss_me  \
# dissolvefield
# 1                41.1662          0  192.0      26.061         20     5903
#
#                adm0_sr  provnum_ne  ...  adm0_label    gn_id    gns_id  \
# dissolvefield                       ...
# 1                    2       40071  ...          10  1727684  18151207
#
#                gn_level  gns_level  min_label  max_label  min_zoom  \
# dissolvefield
# 1                     2          2       20.0       22.0      20.0
#
#                     ne_id  До датум
# dissolvefield
# 1              2318629040       0.0
#
# [1 rows x 29 columns]

# %%
quarantine[['geometry', 'population']].to_file("../podatoci/macedonia/covid-quarantine.geojson", 'GeoJSON')

# %%
quarantine
# Out:
#                                                         geometry  latitude  \
# dissolvefield
# 1              POLYGON ((20.68236 41.43111, 20.68161 41.43045...   83.0054
#
#                longitude  area_sqkm   area  population  scalerank  diss_me  \
# dissolvefield
# 1                41.1662          0  192.0      26.061         20     5903
#
#                adm0_sr  provnum_ne  ...  adm0_label    gn_id    gns_id  \
# dissolvefield                       ...
# 1                    2       40071  ...          10  1727684  18151207
#
#                gn_level  gns_level  min_label  max_label  min_zoom  \
# dissolvefield
# 1                     2          2       20.0       22.0      20.0
#
#                     ne_id  До датум
# dissolvefield
# 1              2318629040       0.0
#
# [1 rows x 29 columns]
